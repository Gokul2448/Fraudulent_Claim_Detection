# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
fraud_df = pd.read_csv("insurance_claims.csv")

# %%
# Check at the first few entries
fraud_df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
fraud_df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
fraud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        909 non-null    object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
fraud_df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
#authorities_contacted has 91 entries of None which is wrongly considered as NAN. 
#This is a valid catgeory and can be renamed to a proper field
fraud_df["authorities_contacted"].fillna("None Contacted" ,inplace=True)
fraud_df["authorities_contacted"].value_counts()
# Out:
# authorities_contacted
# Police            292
# Fire              223
# Other             198
# Ambulance         196
# None Contacted     91
# Name: count, dtype: int64

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in fraud_df:
    print(f"\Column : {col}")
    unique_count = fraud_df[col].nunique(dropna=False)
    print(f"Unique values count: {fraud_df[col].nunique(dropna=False)}")
    print(f"Column values: {fraud_df[col].unique()}")
    if(unique_count ==1):
        print(f" column '{col}' might be redudant as it have only 1 unique value")
    
#Note no duplicate entries are found as per the output
#_c39 have only NAN values which needs to be removed
# Out:
# \Column : months_as_customer
# Unique values count: 391
# Column values: [328 228 134 256 137 165  27 212 235 447  60 121 180 473  70 140 160 196
#  460 217 370 413 237   8 257 202 224 241  64 166 155 114 149 147  62 289
#  431 199  79 116  37 106 269 265 163 355 175 192 430  91 223 195  22 439
#   94  11 151 154 245 119 215 295 254 107 478 128 338 271 222 120 270 319
#  194 227 244  78 200 284 275 153  31  41 127  61 207 219  80 325  29 239
#  279 350 464 118 298  87 261 453 210 168 390 258 225 164 255 206 203 211
#  274  81 280 112  24  93 171 124 287 122 398 214 209  82 193 288 104 101
#  375 461 428  45 136 216 278 108  14 276  47  73 294 324  53 426 111  86
#  296 125 177 238 449 252 359  19 285  30 342 468 343 404  63 335 142 272
#   69  38 281 246 330 362 371 377 172  99 249 190 174  95   2 117 242 440
#   20 208 156 232  84 394  35 369 332 243 264  32 259 186 201 436 189 105
#   88  40  59  39 123 231 247  48 267 286 253  10 158   1  85 233 266  97
#  399 305 129 283  96 176 159 290 299  66 334 429  15 230 250  65 475  77
#  229 110 292 451 150 291 162 309 396 273 419 315  72 157 113 115 236   7
#  126 297 406 146 409   6 103 344 437  56 277 138   4 167 467 310 143 102
#  303 152 144 414 352  33 347 410 448 218  43 411 360 300  67 380 389 317
#  191 321   0 405 304  26  12  83 184 479   5 220 316 379 354 169 339 131
#  313 337 204 364 185 251 392 402 182 282 415  51 130 463 472  75   3  98
#   16 438 422  34 183 356 109 198 446 435 434  25 148 145 263  46 234 456
#   58 293 385 100 373 322  76  54  92 173 366 188  89 458 161 476 133 320
#  421 135  57 187 386 197 179 132   9 427  13 312 260 141 441 381 178 425
#   55  90  36 308 412 465 407 205 372 213 240  50  17]
# \Column : age
# Unique values count: 46
# Column values: [48 42 29 41 44 39 34 37 33 61 23 38 58 26 31 62 55 40 35 43 45 25 30 28
#  49 54 47 59 27 56 32 36 64 60 51 46 50 57 53 24 52 19 21 63 20 22]
# \Column : policy_number
# Unique values count: 1000
# Column values: [521585 342868 687698 227811 367455 104594 413978 429027 485665 636550
#  543610 214618 842643 626808 644081 892874 558938 275265 921202 143972
#  183430 431876 285496 115399 736882 699044 863236 608513 914088 596785
#  '2015-01-29' '2015-01-19' '2015-01-01' '2015-02-10' '2015-01-11'
#  '2015-02-24' '2015-01-09' '2015-01-28' '2015-01-07' '2015-01-18'
#  '2015-02-28' '2015-02-12' '2015-01-24' '2015-01-03' '2015-01-16'
#  '2015-02-14' '2015-02-21' '2015-02-18' '2015-02-26' '2015-01-17'
#  '2015-01-27' '2015-02-11' '2015-01-12' '2015-02-06' '2015-01-20'
#  '2015-02-02' '2015-02-20' '2015-02-08' '2015-02-23' '2015-03-01'
#  '2015-01-14' '2015-02-19' '2015-02-09' '2015-01-26' '2015-01-23'
#  '2015-01-31' '2015-02-03' '2015-02-01' '2015-02-05' '2015-02-25'
#  '2015-02-16' '2015-02-13' '2015-02-04' '2015-02-07' '2015-01-04']
# \Column : incident_type
# Unique values count: 4
# Column values: ['Single Vehicle Collision' 'Vehicle Theft' 'Multi-vehicle Collision'
#  'Parked Car']
# \Column : collision_type
# Unique values count: 4
# Column values: ['Side Collision' '?' 'Rear Collision' 'Front Collision']
# \Column : incident_severity
# Unique values count: 4
# Column values: ['Major Damage' 'Minor Damage' 'Total Loss' 'Trivial Damage']
# \Column : authorities_contacted
# Unique values count: 5
# Column values: ['Police' 'None Contacted' 'Fire' 'Other' 'Ambulance']
# \Column : incident_state
# Unique values count: 7
# Column values: ['SC' 'VA' 'NY' 'OH' 'WV' 'NC' 'PA']
# \Column : incident_city
# Unique values count: 7
# Column values: ['Columbus' 'Riverwood' 'Arlington' 'Springfield' 'Hillsdale' 'Northbend'
#  'Northbrook']
# \Column : incident_location
# Unique values count: 1000
# Column values: ['9935 4th Drive' '6608 MLK Hwy' '7121 Francis Lane' '6956 Maple Drive'
#  '3041 3rd Ave' '8973 Washington St' '5846 Weaver Drive' '3525 3rd Hwy'
#  '4872 Rock Ridge' '3066 Francis Ave' '1558 1st Ridge' '5971 5th Hwy'
#  '6655 5th Drive' '6582 Elm Lane' '6851 3rd Drive' '9573 Weaver Ave'
#  '5074 3rd St' '4546 Tree St' '3842 Solo Ridge' '8101 3rd Ridge'
#  '5380 Pine St' '8957 Weaver Drive' '2526 Embaracadero Ave'
#  '5667 4th Drive' '2502 Apache Hwy' '3418 Texas Lane' '2533 Elm St'
#  '3790 Andromedia Hwy' '3220 Rock Drive' '2100 Francis Drive'
#  '4687 5th Drive' '9038 2nd Lane' '6092 5th Ave' '8353 Britain Ridge'
#  '3540 Maple St' '3104 Sky Drive' '4981 Weaver St' '6676 Tree Lane'
#  '3930 Embaracadero St' '3422 Flute St' '4862 Lincoln Hwy' '5719 2nd Lane'
#  '3221 Solo Ridge' '6660 MLK Drive' '1699 Oak Drive' '4234 Cherokee Lane'
#  '7476 4th St' '8907 Tree Ave' '6619 Flute Ave' '6011 Britain St'
#  '5104 Francis Drive' '2280 4th Ave' '2644 Elm Drive' '7466 MLK Ridge'
#  '5821 2nd St' '6723 Best Drive' '4866 4th Hwy' '5418 Britain Ave'
#  '4296 Pine Hwy' '2299 1st St' '6618 Cherokee Drive' '7459 Flute St'
#   6480 42770 64800  2940 25020 49210 19110 39040 35100 58870 47880 33180
#  40390 74790 21520 59220 55760 25480 28140 50330 45180 49770 40000 35370
#  38520 58860 43330  4690  3570 50680 49980 50890 69210 52000  4000 36300
#  34960 35000 53730  6090 46200 39920 53840 39130 49490 32480 25150 34240
#  32560  2400 62000 54630 63920 56140 43040 40770 39520  2080 40640 31140
#  65200 39690 50940 37760 38880 45680 47810  3680 39600 54390 43750 57960
#  36270 76000  2730 46830 30520 43960 41650 26530 44170 47160 46400 44160
#  49080 24240 26040  2880 24360 47040  1760  4400 34160 29280 61650 37440
#  45840 46160 32320 57900 34400 40080 28240 46300 30240 59490 67590 45850
#  56160 49860 36640 44550 38780 49920 73260  5200 33480  3710 51540  4740
#  26880 51520 62640 59760 35210 30940 54540 56960 72720 40560 34560 42240
#  32200  6300 27200 54160 20510 55600 57610 28980 27660 57520 61530 59680
#  32240 43400 40500 44730 43260 46960 49350 34740 50640 24640    70 43820
#  57060 60660 35920  2380 26080 38500 42960 22120 42930 42120 33300 67440
#  21490 39620  2640 63600 56980 54740  3640 43740 43760 54400 32800 48480
#  37100 41680 41300 42350 61760 44400  3420 45200 56880 37360 36120  3870
#  48090 27860 43680 36890 53340 58410  4560 60720 38430 29750 37450 65920
#  40680 59360 47740 49700 29680 46270  5390 40960 38080 26720 54530 29890
#  53120 38000 37730  1980  6210 38640 47360 55520 32400 45000 44880 51440
#   4500 71820  2800 32160 41600 55120 23760 66560 54320 35980 32520 40740
#  43080 29820 54950 55090 47700 45440 31570 52920  5520 72320 37940 36260
#   4800 53920 47460 34370 75600 39960 53830 34720 67230 36330 34260 53900
#  42490 26670 25690  4860 61040 52500]
# \Column : auto_make
# Unique values count: 14
# Column values: ['Saab' 'Mercedes' 'Dodge' 'Chevrolet' 'Accura' 'Nissan' 'Audi' 'Toyota'
#  'Ford' 'Suburu' 'BMW' 'Jeep' 'Honda' 'Volkswagen']
# \Column : auto_model
# Unique values count: 39
# Column values: ['92x' 'E400' 'RAM' 'Tahoe' 'RSX' '95' 'Pathfinder' 'A5' 'Camry' 'F150'
#  'A3' 'Highlander' 'Neon' 'MDX' 'Maxima' 'Legacy' 'TL' 'Impreza'
#  'Forrestor' 'Escape' 'Corolla' '3 Series' 'C300' 'Wrangler' 'M5' 'X5'
#  'Civic' 'Passat' 'Silverado' 'CRV' '93' 'Accord' 'X6' 'Malibu' 'Fusion'
#  'Jetta' 'ML350' 'Ultima' 'Grand Cherokee']
# \Column : auto_year
# Unique values count: 21
# Column values: [2004 2007 2014 2009 2003 2012 2015 1996 2002 2006 2000 2010 1999 2011
#  2005 2008 1995 2001 1998 1997 2013]
# \Column : fraud_reported
# Unique values count: 2
# Column values: ['Y' 'N']
# \Column : _c39
# Unique values count: 1
# Column values: [nan]
#  column '_c39' might be redudant as it have only 1 unique value

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
#column _c39 has completely nan value . So removing it

fraud_df =fraud_df.drop('_c39',axis=1)

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
print(fraud_df["authorities_contacted"].value_counts())
print("\n")
print(fraud_df["incident_state"].value_counts())
print("\n")
print(fraud_df["incident_city"].value_counts())
print("\n")
print(fraud_df["incident_hour_of_the_day"].value_counts())
print("\n")
print(fraud_df["number_of_vehicles_involved"].value_counts())
print("\n")
print(fraud_df["property_damage"].value_counts())
print("\n")
print(fraud_df["bodily_injuries"].value_counts())
print("\n")
print(fraud_df["witnesses"].value_counts())
print("\n")
print(fraud_df["insured_sex"].value_counts())
print("\n")
print(fraud_df["insured_education_level"].value_counts())
print("\n")
print(fraud_df["insured_occupation"].value_counts())
print("\n")
print(fraud_df["insured_hobbies"].value_counts())
print("\n")
print(fraud_df["insured_relationship"].value_counts())
print("\n")
print(fraud_df["incident_type"].value_counts())
print("\n")
print(fraud_df["collision_type"].value_counts())
print("\n")
print(fraud_df["incident_severity"].value_counts())
print("\n")
print(fraud_df["police_report_available"].value_counts())
print("\n")
print(fraud_df["auto_make"].value_counts())
print("\n")
print(fraud_df["auto_model"].value_counts())
print("\n")
print(fraud_df["auto_year"].value_counts())
print("\n")
print(fraud_df["fraud_reported"].value_counts())
print("\n")
# Out:
# authorities_contacted
# Police            292
# Fire              223
# Other             198
# Ambulance         196
# None Contacted     91
# Name: count, dtype: int64
#
#
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
#
#
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
#
#
# incident_hour_of_the_day
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 13    46
# 10    46
# 4     46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 12    40
# 19    40
# 7     40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: count, dtype: int64
#
#
# number_of_vehicles_involved
# 1    581
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
#
#
# property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
#
#
# bodily_injuries
# 0    340
# 2    332
# 1    328
# Name: count, dtype: int64
#
#
# witnesses
# 1    258
# 2    250
# 0    249
# 3    243
# Name: count, dtype: int64
#
#
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
#
#
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
#
#
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
#
#
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
#
#
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
#
#
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
#
#
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
#
#
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
#
#
# police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64
#
#
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
#
#
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
#
#
# auto_year
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2009    50
# 2010    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: count, dtype: int64
#
#
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
#Dropping auto_year and auto_make as auto_model can give insights around the same info
fraud_df = fraud_df.drop('auto_make' ,axis =1)
fraud_df = fraud_df.drop('auto_year' ,axis =1)

# %%
# Check the dataset
print(fraud_df.shape)
print("\n")
print(fraud_df.info())
print("\n")
print(fraud_df.isna().sum())
# Out:
# (1000, 37)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_model                   1000 non-null   object
#  36  fraud_reported               1000 non-null   object
# dtypes: float64(1), int64(16), object(20)
# memory usage: 289.2+ KB
# None
#
#
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_model                     0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
#policy_bind_date and incident_date is currently object type. Converting them to datetime
fraud_df["policy_bind_date"] = pd.to_datetime(fraud_df["policy_bind_date"], format='mixed', dayfirst = True)
fraud_df["incident_date"] = pd.to_datetime(fraud_df["incident_date"], format='mixed', dayfirst = True)

# %%
# Check the features of the data again
fraud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   datetime64[ns]
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   datetime64[ns]
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_model                   1000 non-null   object
#  36  fraud_reported               1000 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(16), object(18)
# memory usage: 289.2+ KB

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = fraud_df.drop('fraud_reported',axis =1)
# Put the target variable in y
y = fraud_df["fraud_reported"]

y.head()
# Out:
# 0    Y
# 1    Y
# 2    N
# 3    Y
# 4    N
# Name: fraud_reported, dtype: object

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validaettion and use stratification on the target variable
X_train , X_test ,y_train, y_test = train_test_split (X ,y ,train_size=0.7 ,random_state=42)
print(X_train.shape , "," ,X_test.shape)
# Reset index for all train and test sets
X_train.reset_index(inplace=True, drop =True)
X_test.reset_index(inplace=True, drop =True)
y_train.reset_index(inplace=True, drop =True)
y_test.reset_index(inplace=True, drop =True)
# Out:
# (700, 36) , (300, 36)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
num_columns = X_train.select_dtypes(include=["int64","float64"]).columns
num_columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim',
#        'vehicle_claim'],
#       dtype='object')

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
for col in num_columns:
    sns.boxplot(data=X_train ,y=col)
    plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
X_cor =X_train[num_columns]
print(X_cor.corr())
# Plot Heatmap of the correlation matrix
plt.figure(figsize=(15,10))
sns.heatmap(X_cor.corr() ,cmap="coolwarm" ,annot=True)
plt.show()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.928464       0.054413
# age                                    0.928464  1.000000       0.062774
# policy_number                          0.054413  0.062774       1.000000
# policy_deductable                      0.035420  0.036786      -0.020572
# policy_annual_premium                  0.034705  0.054285       0.014293
# umbrella_limit                         0.008220  0.005851      -0.022513
# insured_zip                            0.039612  0.034870       0.002318
# capital-gains                          0.003327 -0.012263       0.016286
# capital-loss                           0.021819  0.011418      -0.004377
# incident_hour_of_the_day               0.058467  0.077892      -0.026701
# number_of_vehicles_involved            0.017111  0.029891      -0.002253
# bodily_injuries                       -0.031500 -0.022743       0.004699
# witnesses                              0.061854  0.043343      -0.012154
# total_claim_amount                     0.027844  0.021977      -0.048000
# injury_claim                           0.047036  0.042083      -0.040002
# property_claim                         0.003848  0.021413      -0.033682
# vehicle_claim                          0.025711  0.014249      -0.048078
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.035420               0.034705
# age                                   0.036786               0.054285
# policy_number                        -0.020572               0.014293
# policy_deductable                     1.000000              -0.015958
# policy_annual_premium                -0.015958               1.000000
# umbrella_limit                       -0.014925              -0.010070
# insured_zip                           0.015438               0.041036
# capital-gains                         0.064740               0.001753
# capital-loss                         -0.021659               0.026594
# incident_hour_of_the_day              0.061939               0.027435
# number_of_vehicles_involved           0.025584              -0.042219
# bodily_injuries                      -0.064092               0.056265
# witnesses                             0.057188               0.006507
# total_claim_amount                    0.004868               0.028740
# injury_claim                          0.034140               0.013235
# property_claim                        0.036314               0.007740
# vehicle_claim                        -0.011490               0.034799
#
#                              umbrella_limit  insured_zip  capital-gains  \
# months_as_customer                 0.008220     0.039612       0.003327
# age                                0.005851     0.034870      -0.012263
# policy_number                     -0.022513     0.002318       0.016286
# policy_deductable                 -0.014925     0.015438       0.064740
# policy_annual_premium             -0.010070     0.041036       0.001753
# umbrella_limit                     1.000000     0.015168      -0.062538
# insured_zip                        0.015168     1.000000       0.046241
# capital-gains                     -0.062538     0.046241       1.000000
# capital-loss                      -0.025356     0.083056      -0.052645
# incident_hour_of_the_day          -0.023566     0.014890      -0.003707
# number_of_vehicles_involved       -0.002317     0.024765       0.066114
# bodily_injuries                    0.011370     0.050053       0.038829
# witnesses                         -0.012569     0.013001      -0.035091
# total_claim_amount                -0.042919    -0.024912      -0.011207
# injury_claim                      -0.042538     0.000084       0.011000
# property_claim                    -0.019487    -0.016507      -0.029773
# vehicle_claim                     -0.043964    -0.030655      -0.010883
#
#                              capital-loss  incident_hour_of_the_day  \
# months_as_customer               0.021819                  0.058467
# age                              0.011418                  0.077892
# policy_number                   -0.004377                 -0.026701
# policy_deductable               -0.021659                  0.061939
# policy_annual_premium            0.026594                  0.027435
# umbrella_limit                  -0.025356                 -0.023566
# insured_zip                      0.083056                  0.014890
# capital-gains                   -0.052645                 -0.003707
# capital-loss                     1.000000                 -0.037264
# incident_hour_of_the_day        -0.037264                  1.000000
# number_of_vehicles_involved     -0.016135                  0.117887
# bodily_injuries                 -0.040260                 -0.030181
# witnesses                       -0.036192                 -0.019995
# total_claim_amount              -0.045267                  0.213462
# injury_claim                    -0.058896                  0.178163
# property_claim                  -0.020374                  0.151833
# vehicle_claim                   -0.042747                  0.213207
#
#                              number_of_vehicles_involved  bodily_injuries  \
# months_as_customer                              0.017111        -0.031500
# age                                             0.029891        -0.022743
# policy_number                                  -0.002253         0.004699
# policy_deductable                               0.025584        -0.064092
# policy_annual_premium                          -0.042219         0.056265
# umbrella_limit                                 -0.002317         0.011370
# insured_zip                                     0.024765         0.050053
# capital-gains                                   0.066114         0.038829
# capital-loss                                   -0.016135        -0.040260
# incident_hour_of_the_day                        0.117887        -0.030181
# number_of_vehicles_involved                     1.000000         0.020947
# bodily_injuries                                 0.020947         1.000000
# witnesses                                      -0.047805        -0.046943
# total_claim_amount                              0.233480         0.029190
# injury_claim                                    0.208864         0.023351
# property_claim                                  0.157716         0.044372
# vehicle_claim                                   0.231701         0.023320
#
#                              witnesses  total_claim_amount  injury_claim  \
# months_as_customer            0.061854            0.027844      0.047036
# age                           0.043343            0.021977      0.042083
# policy_number                -0.012154           -0.048000     -0.040002
# policy_deductable             0.057188            0.004868      0.034140
# policy_annual_premium         0.006507            0.028740      0.013235
# umbrella_limit               -0.012569           -0.042919     -0.042538
# insured_zip                   0.013001           -0.024912      0.000084
# capital-gains                -0.035091           -0.011207      0.011000
# capital-loss                 -0.036192           -0.045267     -0.058896
# incident_hour_of_the_day     -0.019995            0.213462      0.178163
# number_of_vehicles_involved  -0.047805            0.233480      0.208864
# bodily_injuries              -0.046943            0.029190      0.023351
# witnesses                     1.000000           -0.043821     -0.063070
# total_claim_amount           -0.043821            1.000000      0.802541
# injury_claim                 -0.063070            0.802541      1.000000
# property_claim                0.042960            0.807663      0.555994
# vehicle_claim                -0.055993            0.982300      0.719089
#
#                              property_claim  vehicle_claim
# months_as_customer                 0.003848       0.025711
# age                                0.021413       0.014249
# policy_number                     -0.033682      -0.048078
# policy_deductable                  0.036314      -0.011490
# policy_annual_premium              0.007740       0.034799
# umbrella_limit                    -0.019487      -0.043964
# insured_zip                       -0.016507      -0.030655
# capital-gains                     -0.029773      -0.010883
# capital-loss                      -0.020374      -0.042747
# incident_hour_of_the_day           0.151833       0.213207
# number_of_vehicles_involved        0.157716       0.231701
# bodily_injuries                    0.044372       0.023320
# witnesses                          0.042960      -0.055993
# total_claim_amount                 0.807663       0.982300
# injury_claim                       0.555994       0.719089
# property_claim                     1.000000       0.727645
# vehicle_claim                      0.727645       1.000000

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
y_train.value_counts().plot.bar()
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

categ_columns = X_train.select_dtypes(include=["object","datetime64"]).columns
for col in categ_columns:
    data1 = X_train[[col]]
    data2 = pd.DataFrame(y_train)
    data1 = pd.concat([data1,data2],axis=1)
    data1 = data1[data1['fraud_reported'].isin(['Y'])]
    count = data1[col].value_counts()
    plt.figure(figsize=(8,4))
    sns.barplot(x=count.values, y= count.index, palette ="viridis")
    plt.title(f"Fraude reported by {col}")
    plt.xlabel("Count of Y (Fraud)")
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
for col in num_columns:
    data1 = X_train[[col]]
    data2 = pd.DataFrame(y_train)
    data1 = pd.concat([data1,data2],axis=1)
    sns.jointplot(x = col , y = 'fraud_reported', data =data1)
    plt.title(col)
    plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns
num_columns2 = X_test.select_dtypes(include=["int64","float64"]).columns
num_columns2
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim',
#        'vehicle_claim'],
#       dtype='object')

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution
for col in num_columns2:
    sns.boxplot(data=X_test ,y=col)
    plt.show()

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
X_cor =X_test[num_columns2]
print(X_cor.corr())
# Plot Heatmap of the correlation matrix
plt.figure(figsize=(15,10))
sns.heatmap(X_cor.corr() ,cmap="coolwarm" ,annot=True)
plt.show()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.905632       0.057308
# age                                    0.905632  1.000000       0.042610
# policy_number                          0.057308  0.042610       1.000000
# policy_deductable                      0.002586  0.006724       0.026035
# policy_annual_premium                 -0.070457 -0.088996       0.043929
# umbrella_limit                         0.033718  0.048659       0.085273
# insured_zip                           -0.027275  0.009485       0.021184
# capital-gains                          0.004849 -0.004053      -0.010939
# capital-loss                           0.020278  0.001857      -0.007099
# incident_hour_of_the_day               0.094536  0.104526       0.063813
# number_of_vehicles_involved            0.013774  0.008724       0.053166
# bodily_injuries                        0.034880 -0.003759      -0.029012
# witnesses                              0.066572  0.093467      -0.006703
# total_claim_amount                     0.124885  0.165259       0.045573
# injury_claim                           0.092713  0.139401       0.060139
# property_claim                         0.095393  0.142636       0.039535
# vehicle_claim                          0.126528  0.159139       0.038381
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.002586              -0.070457
# age                                   0.006724              -0.088996
# policy_number                         0.026035               0.043929
# policy_deductable                     1.000000               0.029510
# policy_annual_premium                 0.029510               1.000000
# umbrella_limit                        0.072348               0.003324
# insured_zip                          -0.020512               0.010795
# capital-gains                        -0.040857              -0.055115
# capital-loss                         -0.027245               0.016345
# incident_hour_of_the_day              0.057366              -0.076268
# number_of_vehicles_involved           0.112934              -0.055322
# bodily_injuries                       0.075048              -0.047334
# witnesses                             0.094876              -0.008195
# total_claim_amount                    0.061840              -0.040127
# injury_claim                          0.047941              -0.097325
# property_claim                        0.131241              -0.061593
# vehicle_claim                         0.041185              -0.015956
#
#                              umbrella_limit  insured_zip  capital-gains  \
# months_as_customer                 0.033718    -0.027275       0.004849
# age                                0.048659     0.009485      -0.004053
# policy_number                      0.085273     0.021184      -0.010939
# policy_deductable                  0.072348    -0.020512      -0.040857
# policy_annual_premium              0.003324     0.010795      -0.055115
# umbrella_limit                     1.000000     0.029706      -0.009874
# insured_zip                        0.029706     1.000000      -0.088805
# capital-gains                     -0.009874    -0.088805       1.000000
# capital-loss                      -0.021405    -0.028174      -0.031700
# incident_hour_of_the_day          -0.022147    -0.005806      -0.050883
# number_of_vehicles_involved       -0.064750     0.032416       0.053267
# bodily_injuries                    0.049186    -0.019710       0.095253
# witnesses                          0.006510     0.032505       0.035899
# total_claim_amount                -0.033634    -0.049930       0.073103
# injury_claim                      -0.051254    -0.054346       0.054760
# property_claim                    -0.032962     0.019620       0.064156
# vehicle_claim                     -0.025655    -0.060654       0.071867
#
#                              capital-loss  incident_hour_of_the_day  \
# months_as_customer               0.020278                  0.094536
# age                              0.001857                  0.104526
# policy_number                   -0.007099                  0.063813
# policy_deductable               -0.027245                  0.057366
# policy_annual_premium            0.016345                 -0.076268
# umbrella_limit                  -0.021405                 -0.022147
# insured_zip                     -0.028174                 -0.005806
# capital-gains                   -0.031700                 -0.050883
# capital-loss                     1.000000                  0.004209
# incident_hour_of_the_day         0.004209                  1.000000
# number_of_vehicles_involved     -0.012967                  0.129167
# bodily_injuries                  0.012207                 -0.046320
# witnesses                       -0.057340                  0.079192
# total_claim_amount              -0.012681                  0.224420
# injury_claim                    -0.013717                  0.132203
# property_claim                  -0.026185                  0.242788
# vehicle_claim                   -0.007650                  0.218217
#
#                              number_of_vehicles_involved  bodily_injuries  \
# months_as_customer                              0.013774         0.034880
# age                                             0.008724        -0.003759
# policy_number                                   0.053166        -0.029012
# policy_deductable                               0.112934         0.075048
# policy_annual_premium                          -0.055322        -0.047334
# umbrella_limit                                 -0.064750         0.049186
# insured_zip                                     0.032416        -0.019710
# capital-gains                                   0.053267         0.095253
# capital-loss                                   -0.012967         0.012207
# incident_hour_of_the_day                        0.129167        -0.046320
# number_of_vehicles_involved                     1.000000        -0.000789
# bodily_injuries                                -0.000789         1.000000
# witnesses                                       0.063478         0.101326
# total_claim_amount                              0.372482         0.084353
# injury_claim                                    0.267313         0.100077
# property_claim                                  0.365707         0.026070
# vehicle_claim                                   0.359444         0.085619
#
#                              witnesses  total_claim_amount  injury_claim  \
# months_as_customer            0.066572            0.124885      0.092713
# age                           0.093467            0.165259      0.139401
# policy_number                -0.006703            0.045573      0.060139
# policy_deductable             0.094876            0.061840      0.047941
# policy_annual_premium        -0.008195           -0.040127     -0.097325
# umbrella_limit                0.006510           -0.033634     -0.051254
# insured_zip                   0.032505           -0.049930     -0.054346
# capital-gains                 0.035899            0.073103      0.054760
# capital-loss                 -0.057340           -0.012681     -0.013717
# incident_hour_of_the_day      0.079192            0.224420      0.132203
# number_of_vehicles_involved   0.063478            0.372482      0.267313
# bodily_injuries               0.101326            0.084353      0.100077
# witnesses                     1.000000            0.083316      0.086312
# total_claim_amount            0.083316            1.000000      0.808113
# injury_claim                  0.086312            0.808113      1.000000
# property_claim                0.088970            0.815977      0.577625
# vehicle_claim                 0.071944            0.983630      0.728064
#
#                              property_claim  vehicle_claim
# months_as_customer                 0.095393       0.126528
# age                                0.142636       0.159139
# policy_number                      0.039535       0.038381
# policy_deductable                  0.131241       0.041185
# policy_annual_premium             -0.061593      -0.015956
# umbrella_limit                    -0.032962      -0.025655
# insured_zip                        0.019620      -0.060654
# capital-gains                      0.064156       0.071867
# capital-loss                      -0.026185      -0.007650
# incident_hour_of_the_day           0.242788       0.218217
# number_of_vehicles_involved        0.365707       0.359444
# bodily_injuries                    0.026070       0.085619
# witnesses                          0.088970       0.071944
# total_claim_amount                 0.815977       0.983630
# injury_claim                       0.577625       0.728064
# property_claim                     1.000000       0.739800
# vehicle_claim                      0.739800       1.000000

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance
y_test.value_counts().plot.bar()
plt.show()

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
categ_columns_test = X_test.select_dtypes(include=["object","datetime64"]).columns
for col in categ_columns_test:
    data1 = X_test[[col]]
    data2 = pd.DataFrame(y_test)
    data1 = pd.concat([data1,data2],axis=1)
    data1 = data1[data1['fraud_reported'].isin(['Y'])]
    count = data1[col].value_counts()
    plt.figure(figsize=(8,4))
    sns.barplot(x=count.values, y= count.index, palette ="viridis")
    plt.title(f"Fraude reported by {col}")
    plt.xlabel("Count of Y (Fraud)")
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
for col in num_columns2:
    data1 = X_test[[col]]
    data2 = pd.DataFrame(y_test)
    data1 = pd.concat([data1,data2],axis=1)
    sns.jointplot(x = col , y = 'fraud_reported', data =data1)
    plt.title(col)
    plt.show()

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
ros =RandomOverSampler(random_state=42)
X_res ,y_res = ros.fit_resample(X_train ,y_train)

out =pd.DataFrame(y_train)
print("Before resampling value \n" , out.value_counts() )

out =pd.DataFrame(y_res)
print("After resampling value \n" , out.value_counts() )
# Out:
# Before resampling value
#  fraud_reported
# N                 533
# Y                 167
# Name: count, dtype: int64
# After resampling value
#  fraud_reported
# N                 533
# Y                 533
# Name: count, dtype: int64

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data
X_res['incident_day'] = X_res['incident_date'].dt.day_name()
X_test['incident_day'] = X_test['incident_date'].dt.day_name()

X_res['capital_net_gain'] = X_res['capital-gains'] - X_res['capital-loss']
X_test['capital_net_gain'] = X_test['capital-gains'] - X_test['capital-loss']

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
X_res = X_res.drop('policy_number',axis=1)
X_res = X_res.drop('incident_date',axis=1)
X_res = X_res.drop('age',axis=1)
X_res = X_res.drop('injury_claim',axis=1)
X_res = X_res.drop('property_claim',axis=1)
X_res = X_res.drop('vehicle_claim',axis=1)
X_res = X_res.drop('policy_bind_date',axis=1)
X_res = X_res.drop('insured_education_level',axis=1)
X_res = X_res.drop('insured_occupation',axis=1)
X_res = X_res.drop('insured_hobbies',axis=1)
X_res = X_res.drop('insured_relationship',axis=1)
X_res = X_res.drop('incident_location',axis=1)
X_res = X_res.drop('incident_state',axis=1)
X_res = X_res.drop('capital-loss',axis=1)
X_res = X_res.drop('capital-gains',axis=1)

X_test = X_test.drop('policy_number',axis=1)
X_test = X_test.drop('incident_date',axis=1)
X_test = X_test.drop('age',axis=1)
X_test = X_test.drop('injury_claim',axis=1)
X_test = X_test.drop('property_claim',axis=1)
X_test = X_test.drop('vehicle_claim',axis=1)
X_test = X_test.drop('policy_bind_date',axis=1)
X_test = X_test.drop('insured_education_level',axis=1)
X_test = X_test.drop('insured_occupation',axis=1)
X_test = X_test.drop('insured_hobbies',axis=1)
X_test = X_test.drop('insured_relationship',axis=1)
X_test = X_test.drop('incident_location',axis=1)
X_test = X_test.drop('incident_state',axis=1)
X_test = X_test.drop('capital-loss',axis=1)
X_test = X_test.drop('capital-gains',axis=1)

#keeping a data copy to use later
X_test_backup = X_test.copy()
X_test_backup = X_test_backup.drop("incident_hour_of_the_day",axis=1)
num_columns = X_test_backup.select_dtypes(include=['int64','float64']).columns

# %%
# Check the data
print("X_res value is \n" , X_res.info())
print("X_test value is \n" , X_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1066 entries, 0 to 1065
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1066 non-null   int64
#  1   policy_state                 1066 non-null   object
#  2   policy_csl                   1066 non-null   object
#  3   policy_deductable            1066 non-null   int64
#  4   policy_annual_premium        1066 non-null   float64
#  5   umbrella_limit               1066 non-null   int64
#  6   insured_zip                  1066 non-null   int64
#  7   insured_sex                  1066 non-null   object
#  8   incident_type                1066 non-null   object
#  9   collision_type               1066 non-null   object
#  10  incident_severity            1066 non-null   object
#  11  authorities_contacted        1066 non-null   object
#  12  incident_city                1066 non-null   object
#  13  incident_hour_of_the_day     1066 non-null   int64
#  14  number_of_vehicles_involved  1066 non-null   int64
#  15  property_damage              1066 non-null   object
#  16  bodily_injuries              1066 non-null   int64
#  17  witnesses                    1066 non-null   int64
#  18  police_report_available      1066 non-null   object
#  19  total_claim_amount           1066 non-null   int64
#  20  auto_model                   1066 non-null   object
#  21  incident_day                 1066 non-null   object
#  22  capital_net_gain             1066 non-null   int64
# dtypes: float64(1), int64(10), object(12)
# memory usage: 191.7+ KB
# X_res value is
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           300 non-null    int64
#  1   policy_state                 300 non-null    object
#  2   policy_csl                   300 non-null    object
#  3   policy_deductable            300 non-null    int64
#  4   policy_annual_premium        300 non-null    float64
#  5   umbrella_limit               300 non-null    int64
#  6   insured_zip                  300 non-null    int64
#  7   insured_sex                  300 non-null    object
#  8   incident_type                300 non-null    object
#  9   collision_type               300 non-null    object
#  10  incident_severity            300 non-null    object
#  11  authorities_contacted        300 non-null    object
#  12  incident_city                300 non-null    object
#  13  incident_hour_of_the_day     300 non-null    int64
#  14  number_of_vehicles_involved  300 non-null    int64
#  15  property_damage              300 non-null    object
#  16  bodily_injuries              300 non-null    int64
#  17  witnesses                    300 non-null    int64
#  18  police_report_available      300 non-null    object
#  19  total_claim_amount           300 non-null    int64
#  20  auto_model                   300 non-null    object
#  21  incident_day                 300 non-null    object
#  22  capital_net_gain             300 non-null    int64
# dtypes: float64(1), int64(10), object(12)
# memory usage: 54.0+ KB
# X_test value is
#  None

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
print("**************Before Combining the values*******************")
print(X_res["incident_severity"].value_counts() ,"\n\n")
print(X_res["collision_type"].value_counts(),"\n\n")
print(X_res["property_damage"].value_counts(),"\n\n")
print(X_res["police_report_available"].value_counts())

#Changing the Total Loss  and Trivial Damage in incident_severity to Major Damage and Minor Damage respectively
#Changing the ?  parameters in collision_type and police_report_available
#Changing YES or NO in property_damage and police_report_available to values for better dummy variable creation

X_res["incident_severity"] = X_res["incident_severity"].apply(lambda x: 'Minor Damage' if x == 'Trivial Damage' else x)
X_res["incident_severity"] = X_res["incident_severity"].apply(lambda x: 'Major Damage' if x == 'Total Loss' else x)
X_res["collision_type"] = X_res["collision_type"].apply(lambda x: 'Collision status not known' if x == '?' else x)
X_res["property_damage"] = X_res["property_damage"].apply(lambda x: 'Property damage not known' if x == '?' else x)
X_res["property_damage"] = X_res["property_damage"].apply(lambda x: 'Property damaged' if x == 'YES' else x)
X_res["property_damage"] = X_res["property_damage"].apply(lambda x: 'Property not damaged' if x == 'NO' else x)
X_res["police_report_available"] = X_res["police_report_available"].apply(lambda x: 'Police report not known' if x == '?' else x)
X_res["police_report_available"] = X_res["police_report_available"].apply(lambda x: 'Police report available' if x == 'YES' else x)
X_res["police_report_available"] = X_res["police_report_available"].apply(lambda x: 'Police report not available' if x == 'NO' else x)

X_test["incident_severity"] = X_test["incident_severity"].apply(lambda x: 'Minor Damage' if x == 'Trivial Damage' else x)
X_test["incident_severity"] = X_test["incident_severity"].apply(lambda x: 'Major Damage' if x == 'Total Loss' else x)
X_test["collision_type"] = X_test["collision_type"].apply(lambda x: 'Collision status not known' if x == '?' else x)
X_test["property_damage"] = X_test["property_damage"].apply(lambda x: 'Property damage not known' if x == '?' else x)
X_test["property_damage"] = X_test["property_damage"].apply(lambda x: 'Property damaged' if x == 'YES' else x)
X_test["property_damage"] = X_test["property_damage"].apply(lambda x: 'Property not damaged' if x == 'NO' else x)
X_test["police_report_available"] = X_test["police_report_available"].apply(lambda x: 'Police report not known' if x == '?' else x)
X_test["police_report_available"] = X_test["police_report_available"].apply(lambda x: 'Police report available' if x == 'YES' else x)
X_test["police_report_available"] = X_test["police_report_available"].apply(lambda x: 'Police report not available' if x == 'NO' else x)

print("**************After Combining the values*******************")
print(X_res["incident_severity"].value_counts(),"\n\n")
print(X_res["collision_type"].value_counts(),"\n\n")
print(X_res["property_damage"].value_counts(),"\n\n")
print(X_res["police_report_available"].value_counts())
# Out:
# **************Before Combining the values*******************
# incident_severity
# Major Damage      448
# Minor Damage      300
# Total Loss        258
# Trivial Damage     60
# Name: count, dtype: int64
#
#
# collision_type
# Rear Collision     340
# Front Collision    306
# Side Collision     284
# ?                  136
# Name: count, dtype: int64
#
#
# property_damage
# ?      392
# YES    364
# NO     310
# Name: count, dtype: int64
#
#
# police_report_available
# NO     390
# ?      349
# YES    327
# Name: count, dtype: int64
# **************After Combining the values*******************
# incident_severity
# Major Damage    706
# Minor Damage    360
# Name: count, dtype: int64
#
#
# collision_type
# Rear Collision                340
# Front Collision               306
# Side Collision                284
# Collision status not known    136
# Name: count, dtype: int64
#
#
# property_damage
# Property damage not known    392
# Property damaged             364
# Property not damaged         310
# Name: count, dtype: int64
#
#
# police_report_available
# Police report not available    390
# Police report not known        349
# Police report available        327
# Name: count, dtype: int64

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
print(X_res["policy_state"].value_counts(), "\n\n")
print(X_res["policy_csl"].value_counts(), "\n\n")
print(X_res["insured_sex"].value_counts(), "\n\n")
print(X_res["incident_type"].value_counts(), "\n\n")
print(X_res["collision_type"].value_counts(), "\n\n")
print(X_res["incident_severity"].value_counts(), "\n\n")
print(X_res["authorities_contacted"].value_counts(), "\n\n")
print(X_res["incident_city"].value_counts(), "\n\n")
print(X_res["incident_hour_of_the_day"].value_counts(), "\n\n")
print(X_res["property_damage"].value_counts(), "\n\n")
print(X_res["police_report_available"].value_counts(), "\n\n")
print(X_res["auto_model"].value_counts(), "\n\n")
print(X_res["incident_day"].value_counts(), "\n\n")
# Out:
# policy_state
# OH    378
# IL    361
# IN    327
# Name: count, dtype: int64
#
#
# policy_csl
# 250/500     395
# 100/300     364
# 500/1000    307
# Name: count, dtype: int64
#
#
# insured_sex
# MALE      543
# FEMALE    523
# Name: count, dtype: int64
#
#
# incident_type
# Single Vehicle Collision    481
# Multi-vehicle Collision     449
# Parked Car                   68
# Vehicle Theft                68
# Name: count, dtype: int64
#
#
# collision_type
# Rear Collision                340
# Front Collision               306
# Side Collision                284
# Collision status not known    136
# Name: count, dtype: int64
#
#
# incident_severity
# Major Damage    706
# Minor Damage    360
# Name: count, dtype: int64
#
#
# authorities_contacted
# Police            292
# Fire              259
# Ambulance         226
# Other             225
# None Contacted     64
# Name: count, dtype: int64
#
#
# incident_city
# Springfield    180
# Arlington      166
# Northbend      164
# Hillsdale      154
# Columbus       152
# Riverwood      129
# Northbrook     121
# Name: count, dtype: int64
#
#
# incident_hour_of_the_day
# 23    67
# 0     65
# 16    62
# 21    60
# 17    54
# 18    52
# 11    51
# 3     50
# 14    44
# 13    43
# 12    43
# 6     43
# 19    42
# 10    42
# 7     40
# 20    38
# 4     37
# 2     37
# 15    36
# 8     35
# 22    33
# 9     32
# 5     31
# 1     29
# Name: count, dtype: int64
#
#
# property_damage
# Property damage not known    392
# Property damaged             364
# Property not damaged         310
# Name: count, dtype: int64
#
#
# police_report_available
# Police report not available    390
# Police report not known        349
# Police report available        327
# Name: count, dtype: int64
#
#
# auto_model
# 92x               47
# MDX               46
# Jetta             44
# Wrangler          42
# F150              42
# RAM               38
# E400              38
# Passat            37
# A3                34
# Silverado         32
# Civic             32
# Fusion            32
# Legacy            31
# Neon              30
# Forrestor         30
# ML350             30
# 95                29
# CRV               28
# 93                28
# Malibu            26
# Escape            26
# A5                26
# Grand Cherokee    26
# Camry             24
# Maxima            23
# X5                23
# Pathfinder        23
# M5                20
# TL                20
# X6                20
# C300              19
# 3 Series          19
# Tahoe             17
# Ultima            17
# Highlander        16
# Impreza           16
# Corolla           15
# RSX               13
# Accord             7
# Name: count, dtype: int64
#
#
# incident_day
# Saturday     198
# Wednesday    152
# Sunday       152
# Monday       149
# Thursday     140
# Friday       140
# Tuesday      135
# Name: count, dtype: int64

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
#Dropping first column from dummy
dummy  =pd.get_dummies(X_res["policy_state"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('policy_state' ,axis =1)

dummy  =pd.get_dummies(X_res["policy_csl"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('policy_csl' ,axis =1)

dummy  =pd.get_dummies(X_res["insured_sex"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('insured_sex' ,axis =1)

dummy  =pd.get_dummies(X_res["incident_type"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('incident_type' ,axis =1)

dummy  =pd.get_dummies(X_res["collision_type"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('collision_type' ,axis =1)

dummy  =pd.get_dummies(X_res["incident_severity"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('incident_severity' ,axis =1)

dummy  =pd.get_dummies(X_res["authorities_contacted"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('authorities_contacted' ,axis =1)

dummy  =pd.get_dummies(X_res["incident_city"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('incident_city' ,axis =1)

dummy  =pd.get_dummies(X_res["incident_hour_of_the_day"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('incident_hour_of_the_day' ,axis =1)

dummy  =pd.get_dummies(X_res["property_damage"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('property_damage' ,axis =1)

dummy  =pd.get_dummies(X_res["police_report_available"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('police_report_available' ,axis =1)

dummy  =pd.get_dummies(X_res["auto_model"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('auto_model' ,axis =1)

dummy  =pd.get_dummies(X_res["incident_day"],dtype =int,drop_first =True)
#Add dummy variables to X_res 
X_res = pd.concat([X_res,dummy],axis=1)
X_res = X_res.drop('incident_day' ,axis =1)

X_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1066 entries, 0 to 1065
# Columns: 103 entries, months_as_customer to Wednesday
# dtypes: float64(1), int32(93), int64(9)
# memory usage: 470.7 KB

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
#Dropping first column from dummy
dummy  =pd.get_dummies(X_test["policy_state"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('policy_state' ,axis =1)

dummy  =pd.get_dummies(X_test["policy_csl"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('policy_csl' ,axis =1)

dummy  =pd.get_dummies(X_test["insured_sex"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('insured_sex' ,axis =1)

dummy  =pd.get_dummies(X_test["incident_type"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('incident_type' ,axis =1)

dummy  =pd.get_dummies(X_test["collision_type"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('collision_type' ,axis =1)

dummy  =pd.get_dummies(X_test["incident_severity"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('incident_severity' ,axis =1)

dummy  =pd.get_dummies(X_test["authorities_contacted"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('authorities_contacted' ,axis =1)

dummy  =pd.get_dummies(X_test["incident_city"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('incident_city' ,axis =1)

dummy  =pd.get_dummies(X_test["incident_hour_of_the_day"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('incident_hour_of_the_day' ,axis =1)

dummy  =pd.get_dummies(X_test["property_damage"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('property_damage' ,axis =1)

dummy  =pd.get_dummies(X_test["police_report_available"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('police_report_available' ,axis =1)

dummy  =pd.get_dummies(X_test["auto_model"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('auto_model' ,axis =1)

dummy  =pd.get_dummies(X_test["incident_day"],dtype =int,drop_first =True)
#Add dummy variables to X_test 
X_test = pd.concat([X_test,dummy],axis=1)
X_test = X_test.drop('incident_day' ,axis =1)

X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Columns: 103 entries, months_as_customer to Wednesday
# dtypes: float64(1), int32(93), int64(9)
# memory usage: 132.6 KB

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
y_res["fraud_reported"] = y_res.apply(lambda x: 'Fraud_Yes' if x == 'Y' else 'Fraud_No')
Y = pd.DataFrame(y_res)
# Dropping first column from dummy
dummy = pd.get_dummies(y_res["fraud_reported"],dtype=int, drop_first = True)
# Add dummy variables to y_test dataframe
y_res = pd.concat([y_res , dummy], axis = 1)
y_res = y_res.drop('fraud_reported',axis=1)
Y = pd.DataFrame(y_res)
print("\n", Y.value_counts())

#Adding dummy variables to y_test
y_test["fraud_reported"] = y_test.apply(lambda x: 'Fraud_Yes' if x == 'Y' else 'Fraud_No')
Y = pd.DataFrame(y_test)
# Dropping first column from dummy
dummy = pd.get_dummies(y_test["fraud_reported"],dtype=int, drop_first = True)
# Add dummy variables to y_test dataframe
y_test = pd.concat([y_test , dummy], axis = 1)
y_test = y_test.drop('fraud_reported',axis=1)
Y = pd.DataFrame(y_test)
print("\n", Y.value_counts())
# Out:
#  Fraud_Yes
# 0.0          533
# 1.0          533
# Name: count, dtype: int64
#
#  Fraud_Yes
# 0.0          220
# 1.0           80
# Name: count, dtype: int64

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import MinMaxScaler
scaler =MinMaxScaler()
# Scale the numeric features present in the training data
X_res[num_columns] =scaler.fit_transform(X_res[num_columns])
# Scale the numeric features present in the validation data
X_test[num_columns] =scaler.transform(X_test[num_columns])
print(X_test.describe())
# Out:
#        months_as_customer  policy_deductable  policy_annual_premium  \
# count          300.000000         300.000000             300.000000
# mean             0.398636           0.414444               0.509092
# std              0.240311           0.400314               0.143318
# min              0.002088           0.000000               0.147801
# 25%              0.210856           0.000000               0.411362
# 50%              0.386221           0.333333               0.512848
# 75%              0.551670           1.000000               0.595353
# max              1.000000           1.000000               0.930779
#
#        umbrella_limit  insured_zip  number_of_vehicles_involved  \
# count       300.00000   300.000000                   300.000000
# mean          0.11200     0.385036                     0.288889
# std           0.23188     0.375836                     0.343040
# min          -0.10000     0.002710                     0.000000
# 25%           0.00000     0.114735                     0.000000
# 50%           0.00000     0.200047                     0.000000
# 75%           0.00000     0.904157                     0.666667
# max           1.00000     1.000488                     1.000000
#
#        bodily_injuries   witnesses  total_claim_amount  capital_net_gain  ...  \
# count       300.000000  300.000000          300.000000        300.000000  ...
# mean          0.485000    0.530000            0.434998          0.259250  ...
# std           0.411712    0.351548            0.232911          0.208271  ...
# min           0.000000    0.000000            0.018725          0.000000  ...
# 25%           0.000000    0.333333            0.303519          0.000000  ...
# 50%           0.500000    0.666667            0.489288          0.253125  ...
# 75%           1.000000    0.666667            0.593102          0.394661  ...
# max           1.000000    1.000000            0.910207          0.798438  ...
#
#            Ultima    Wrangler          X5          X6      Monday    Saturday  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.030000    0.030000    0.016667    0.016667    0.126667    0.173333
# std      0.170872    0.170872    0.128233    0.128233    0.333155    0.379168
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            Sunday    Thursday     Tuesday   Wednesday
# count  300.000000  300.000000  300.000000  300.000000
# mean     0.116667    0.156667    0.123333    0.153333
# std      0.321559    0.364094    0.329369    0.360911
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 103 columns]

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Apply RFECV to identify the most relevant features

# %%
# Display the features ranking by RFECV in a DataFrame

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV

# %%
# Import statsmodels and add constant

# Check the data

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data

# Reshape it into an array

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model

# Create new column indicating predicted classifications based on a cutoff value of 0.5

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve


# Define ROC function

# %%
# Call the ROC function

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model

# Create a DataFrame to visualise the importance scores

# %%
# Select features with high importance scores

# Create a new training data with only the selected features

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values

# Best Hyperparameters

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1-Score

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data

# Add constant to X_validation

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity


# Calculate the specificity


# Calculate Precision


# Calculate Recall


# Calculate F1 Score

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data

# Make predictions on the validation data

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate Sensitivity


# Calculate Specificity


# Calculate Precision


# Calculate Recall


# Calculate F1-score

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.
